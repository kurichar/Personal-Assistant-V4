# %% [markdown]
# User sends a **user_message** and it arrives to ([bot.py:63](bot.py#L63)):
# ```python
# add_to_conversation(user_id, {"role": "user", "content": user_message})
# ```
# stored as `{"role": "user", "content": "Create a task to buy milk"}`

# %% [markdown]
# Call LLM ([bot.py:66 ](bot.py#L66)→ [llm_handler.py:70](llm_handler.py#L70)):
# ```python
# response = llm_handler.chat(get_conversation(user_id), tools=tools.ALL_TOOLS)
# ```
